# %% [markdown]
# # 🏥 MedGemma 1.5 DICOM Report Generator
# **By Dr. João Abrantes**
#
# Auto-generate structured radiology reports from DICOM images using Google's MedGemma 1.5 4B model.
#
# ## Setup
# 1. Make sure GPU is enabled: **Runtime > Change runtime type > T4 GPU**
# 2. Add your HuggingFace token to Colab Secrets (key icon on left sidebar): name it `HF_TOKEN`
# 3. Run all cells below
# 4. Click the Gradio public link to open the app

# %%
# Cell 1: Check GPU
# !nvidia-smi --query-gpu=name,memory.total --format=csv,noheader

# %%
# Cell 2: Install dependencies
# !pip install -q gradio>=5.0.0 transformers>=4.52.0 accelerate>=1.4.0 pydicom Pillow scipy python-dotenv huggingface_hub

# %%
# Cell 3: Login to HuggingFace using Colab Secrets
import os
try:
    from google.colab import userdata
    hf_token = userdata.get('HF_TOKEN')
    os.environ['HF_TOKEN'] = hf_token
    print('✅ HF token loaded from Colab Secrets')
except Exception:
    # Fallback: manual input
    from huggingface_hub import login
    login()
    print('✅ Logged in via interactive prompt')

# %%
# Cell 4: Clone the repo
# !git clone https://github.com/JAbrantesRadiology/MedGemma1.5ReportGenerator.git
# %cd MedGemma1.5ReportGenerator

# %%
# Cell 5: Launch the app with a public share link
import os

# Patch app.py to enable share=True for public URL
with open('app.py', 'r') as f:
    code = f.read()
code = code.replace('share=False', 'share=True')
with open('app.py', 'w') as f:
    f.write(code)

print('🚀 Starting MedGemma... (model download takes 2-3 min)')
print('📎 A public Gradio link will appear below when ready')
# !python app.py
