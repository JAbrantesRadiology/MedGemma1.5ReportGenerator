# %% [markdown]
# # 🏥 MedGemma 1.5 DICOM Report Generator
# **By Dr. João Abrantes**
#
# Auto-generate structured radiology reports from DICOM images using Google's MedGemma 1.5 4B model.
#
# ## Setup
# 1. Make sure GPU is enabled: **Runtime > Change runtime type > T4 GPU**
# 2. Run all cells below
# 3. Click the Gradio link to open the app

# %%
# Check GPU
# !nvidia-smi --query-gpu=name,memory.total --format=csv,noheader

# %%
# Install dependencies
# !pip install -q gradio>=5.0.0 transformers>=4.52.0 accelerate>=1.4.0 pydicom Pillow scipy python-dotenv

# %%
# Login to HuggingFace (needed for gated MedGemma model)
from huggingface_hub import login
login()

# %%
# Clone the repo
# !git clone https://github.com/JAbrantesRadiology/MedGemma1.5ReportGenerator.git
# %cd MedGemma1.5ReportGenerator

# %%
# Launch the app with a public share link
import subprocess, os, sys

# Patch app.py to enable share=True
with open('app.py', 'r') as f:
    code = f.read()
code = code.replace('share=False', 'share=True')
with open('app.py', 'w') as f:
    f.write(code)

# Set HF token from login
os.environ['HF_TOKEN'] = os.environ.get('HF_TOKEN', '')

# Run
# !python app.py
